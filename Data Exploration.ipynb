# %% [markdown]
# ## First, import you libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.preprocessing import StandardScaler, normalize
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Then, import your dataset

# %%
df_train = pd.read_csv('train.csv')

# %% [markdown]
# ### Let's see how our dataset looks like

# %%
#Top Rows
df_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %%
df_train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# Alley             object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
#                   ...
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# KitchenQual       object
# TotRmsAbvGrd       int64
# Functional        object
# Fireplaces         int64
# ...

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df_train['GarageYrBlt'].dtype
# Out:
# dtype('float64')

# %%
#Bottom rows
df_train.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
df_train['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
#Pull specific rows and turn visualize as columns
df_train.iloc[0]
# Out:
# Id                    1
# MSSubClass           60
# MSZoning             RL
# LotFrontage        65.0
# LotArea            8450
#                   ...
# MoSold                2
# YrSold             2008
# SaleType             WD
# SaleCondition    Normal
# SalePrice        208500
# Name: 0, Length: 81, dtype: object

# %%
df_train.iloc[:,1]
# Out:
# 0       60
# 1       20
# 2       60
# 3       70
# 4       60
#         ..
# 1455    60
# 1456    20
# 1457    70
# 1458    20
# 1459    20
# Name: MSSubClass, Length: 1460, dtype: int64

# %%
#What are the available columns?
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#descriptive statistics summary of all dataset
df_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df_train['MSSubClass'].max()
# Out:
# 190

# %%
#descriptive statistics summary of a given column dataset
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
#histograms
sns.distplot(df_train['SalePrice']);

# %%
sns.distplot(df_train['LotArea']);

# %%
sns.distplot(df_train['GrLivArea']);

# %%
#skewness of 1.88 and a kurtosis of 6.54 indicate that the distribution has positive skewness and high positive kurtosis, meaning it has a long right tail and a high peak.
print("Skewness: %f" % df_train['SalePrice'].skew())
print("Kurtosis: %f" % df_train['SalePrice'].kurt())
# Out:
# Skewness: 1.882876
# Kurtosis: 6.536282

# %%
#the skewness is 12.207688 which indicates a strong positive skewness and kurtosis is 203.243271 which indicates a very peaked distribution.
print("Skewness: %f" % df_train['LotArea'].skew())
print("Kurtosis: %f" % df_train['LotArea'].kurt())
# Out:
# Skewness: 12.207688
# Kurtosis: 203.243271

# %%
#When you have a strong skewness and peaked distribution in your data, it means that your data is not normally distributed and it can have an impact on your model performance. 
#Here are a few things you can do to handle this issue:

#Transformation: Apply a transformation such as logarithmic, square root or inverse transformation to the data to reduce skewness and kurtosis.

#Standardization: Standardizing the data using mean and standard deviation can also help in reducing skewness and kurtosis.

#Removing Outliers: Removing outliers from the data can also help in reducing skewness and kurtosis.

#Binning: Binning the data into smaller groups and converting it into a categorical variable can also help in reducing skewness and kurtosis.

#Regularization: Using regularization techniques like Lasso, Ridge or Elastic Net during model training can help in reducing the impact of skewed data on the model performance.

# %%
print("Skewness: %f" % df_train['GrLivArea'].skew())
print("Kurtosis: %f" % df_train['GrLivArea'].kurt())
# Out:
# Skewness: 1.366560
# Kurtosis: 4.895121

# %%
scatter1 = pd.concat([df_train['SalePrice'], df_train['LotArea']], axis=1)
print(scatter1)
scatter1.plot.scatter(x='SalePrice', y='LotArea');
# Out:
#       SalePrice  LotArea
# 0        208500     8450
# 1        181500     9600
# 2        223500    11250
# 3        140000     9550
# 4        250000    14260
# ...         ...      ...
# 1455     175000     7917
# 1456     210000    13175
# 1457     266500     9042
# 1458     142125     9717
# 1459     147500     9937
#
# [1460 rows x 2 columns]

# %%
scatter2 = pd.concat([df_train['SalePrice'], df_train['GrLivArea']], axis=1)
scatter2.plot.scatter(x='SalePrice', y='GrLivArea');

# %%
# Show correlations
df_train.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
# Correlation visualization
corrmat = df_train.corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
#The function np.corrcoef calculates the correlation matrix for the given data by taking the transpose of the data
cm = np.corrcoef(df_train[cols].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#Show covariance
df_train.cov()
# Out:
#                           Id     MSSubClass    LotFrontage       LotArea  \
# Id             177755.000000     198.968472    -108.390207 -1.398197e+05
# MSSubClass        198.968472    1789.338306    -404.439075 -5.901742e+04
# LotFrontage      -108.390207    -404.439075     589.749169  8.199814e+04
# LotArea       -139819.667238  -59017.418634   81998.138404  9.962565e+07
# OverallQual       -16.539068       1.908771       8.673047  1.460548e+03
# OverallCond         5.915696      -2.792117      -1.573935 -6.260287e+01
# YearBuilt        -161.881768      35.581337      95.108483  4.289113e+03
# YearRemodAdd     -191.474297      35.439934      45.744675  2.841344e+03
# MasVnrArea      -3842.687941     175.837842     871.207424  1.884014e+05
# BsmtFinSF1       -966.102125   -1347.355751    2635.952669  9.746908e+05
# BsmtFinSF2       -405.884167    -447.979166     187.215374  1.790022e+05
# BsmtUnfSF       -1479.131254   -2630.967059    1445.358556 -1.154799e+04
# ...

# %%
#scatterplot
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols], size = 2.5)
plt.show();

# %% [markdown]
# ### More seaborn plots: https://seaborn.pydata.org/examples/index.html

# %%
# Let's find out how missing data do we have

# First, let's count the number of null values
total = df_train.isnull().sum().sort_values(ascending=False)
# Then, let's calculate the percentage of missing data per feature
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
# Finally, let's concatenate Total and Percent into another dataframe
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#               Total   Percent
# PoolQC         1453  0.995205
# MiscFeature    1406  0.963014
# Alley          1369  0.937671
# Fence          1179  0.807534
# FireplaceQu     690  0.472603
# LotFrontage     259  0.177397
# GarageYrBlt      81  0.055479
# GarageCond       81  0.055479
# GarageType       81  0.055479
# GarageFinish     81  0.055479
# GarageQual       81  0.055479
# BsmtFinType2     38  0.026027
# BsmtExposure     38  0.026027
# BsmtQual         37  0.025342
# BsmtCond         37  0.025342
# BsmtFinType1     37  0.025342
# MasVnrArea        8  0.005479
# MasVnrType        8  0.005479
# Electrical        1  0.000685
# Id                0  0.000000

# %%
df_train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#standardizing data
#np.newaxis is a special object that can be used to increase the number of dimensions of an existing array. It is used to convert a 1D array into a 2D array, or to insert a new axis into an existing array.
saleprice_standardized = StandardScaler().fit_transform(df_train['SalePrice'][:,np.newaxis]);
#This code of line is taking a standardized SalePrice column from the training data and sorting it in ascending order using argsort(). 
#Then, it is slicing the first 20 values using the index [:20] and assigning it to the variable low_range. The purpose of this code is likely to extract the 20 lowest standardized SalePrice values for further analysis.
low_range = saleprice_standardized[saleprice_standardized[:,0].argsort()][:20]
#slicing the last 20 values using the index [:20] and assigning it to the variable high_range. 
high_range= saleprice_standardized[saleprice_standardized[:,0].argsort()][-20:]
print('outer range (low) of the distribution:')
low_range
# Out:
# outer range (low) of the distribution:
# array([[-1.83870376],
#        [-1.83352844],
#        [-1.80092766],
#        [-1.78329881],
#        [-1.77448439],
#        [-1.62337999],
#        [-1.61708398],
#        [-1.58560389],
#        [-1.58560389],
#        [-1.5731    ],
#        [-1.54153178],
#        [-1.52264373],
#        [-1.52264373],
#        [-1.52264373],
#        [-1.51005169],
#        [-1.49263691],
#        [-1.46597958],
#        [-1.44079551],
#        [-1.43449949],
#        [-1.43449949]])

# %%
df_train.shape
# Out:
# (1460, 81)

# %%
print('\nouter range (high) of the distribution:')
high_range
# Out:
# outer range (high) of the distribution:
# array([[3.08604046],
#        [3.1364086 ],
#        [3.226492  ],
#        [3.24696665],
#        [3.26232893],
#        [3.34116765],
#        [3.41280373],
#        [3.57712976],
#        [3.59601781],
#        [3.70305009],
#        [3.82897043],
#        [4.04098249],
#        [4.49634819],
#        [4.71041276],
#        [4.73032076],
#        [5.06214602],
#        [5.42383959],
#        [5.59185509],
#        [7.10289909],
#        [7.22881942]])

# %%
#normalizing data

#saleprice_normalized = normalize(df_train['SalePrice'], norm='l2');
#saleprice_normalized

# %%
#convert categorical variable into dummy
df_countries = pd.read_csv('countries.csv')
df_countries
# Out:
#    Country  Age     Salary Purchased
# 0   France   44  72000.000        No
# 1    Spain   27  48000.000       Yes
# 2  Germany   30  54000.000        No
# 3    Spain   38  61000.000        No
# 4  Germany   40  63777.778       Yes
# 5   France   35  58000.000       Yes
# 6    Spain   38  52000.000        No
# 7   France   48  79000.000       Yes
# 8  Germany   50  83000.000        No
# 9   France   37  67000.000       Yes

# %%
# convert categorical variable into dummy
df_countries_w_dummies = pd.get_dummies(df_countries)

# %%
df_countries_w_dummies
# Out:
#    Age     Salary  Country_France  Country_Germany  Country_Spain  \
# 0   44  72000.000               1                0              0
# 1   27  48000.000               0                0              1
# 2   30  54000.000               0                1              0
# 3   38  61000.000               0                0              1
# 4   40  63777.778               0                1              0
# 5   35  58000.000               1                0              0
# 6   38  52000.000               0                0              1
# 7   48  79000.000               1                0              0
# 8   50  83000.000               0                1              0
# 9   37  67000.000               1                0              0
#
#    Purchased_No  Purchased_Yes
# 0             1              0
# 1             0              1
# 2             1              0
# 3             1              0
# 4             0              1
# 5             0              1
# ...

# %%
df_health = pd.read_csv('Health.csv')

# %%
df_health
# Out:
#   Ethnicity  Height (CM)  Weight (Kg) Will survive till 70
# 0     White        186.0         90.0                  Yes
# 1   African        185.0         98.0                   No
# 2     Asian        175.0         80.0                   No
# 3     White        180.0         88.0                  Yes
# 4     Asian        178.0          NaN                   No
# 5     Asian        172.0         72.0                  Yes
# 6   African        178.0         75.0                   No
# 7     White          NaN         89.0                  Yes
# 8   African        186.0         90.0                  Yes

# %%
df_health_dummies=pd.get_dummies(df_health)

# %%
df_health_dummies
# Out:
#    Height (CM)  Weight (Kg)  Ethnicity_African  Ethnicity_Asian  \
# 0        186.0         90.0                  0                0
# 1        185.0         98.0                  1                0
# 2        175.0         80.0                  0                1
# 3        180.0         88.0                  0                0
# 4        178.0          NaN                  0                1
# 5        172.0         72.0                  0                1
# 6        178.0         75.0                  1                0
# 7          NaN         89.0                  0                0
# 8        186.0         90.0                  1                0
#
#    Ethnicity_White  Will survive till 70_No  Will survive till 70_Yes
# 0                1                        0                         1
# 1                0                        1                         0
# 2                0                        1                         0
# ...

# %%
sns.boxplot(df_train['SalePrice'])
